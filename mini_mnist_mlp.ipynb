# %%
import numpy as np
from abc import ABC, abstractmethod

class Layer(ABC):
    
    def __init__(self):
        self.__prevIn__ = []
        self.__prevOut__ = []
        
    def setPrevIn(self, dataIn):
        self.__prevIn = dataIn
        
    def setPrevOut(self, out):
        self.__prevOut = out
        
    def getPrevIn(self):
        return self.__prevIn
    
    def getPrevOut(self):
        return self.__prevOut
    
    def backward(self, gradIn):
        return (gradIn @ self.gradient())
    
    @abstractmethod
    def forward(self, dataIn):
        pass
    
    @abstractmethod
    def gradient(self):
        pass

class HardSigLayer(Layer):
    def __init__(self):
        super().__init__()
    
    def forward(self, dataIn):
        self.setPrevIn(dataIn)      
        z = torch.clip(self.getPrevIn(), -1, 1)
        self.setPrevOut(z)
        return self.getPrevOut()
        
    def gradient(self): 
        z = (self.getPrevOut() > -1) & (self.getPrevOut() < 1)
        return z

# %%
# Mini MNIST MLP to Match Equilibrium Propagation

import numpy as np
from sklearn import datasets

#Load mini MNIST data
digits = datasets.load_digits()
data = digits.data
targets = digits.target

#Standardize data
inputs = data - np.mean(data)
inputs = inputs/(np.std(data))

# %%
print(inputs.shape)
print(targets.shape)
# Out:
# (1797, 64)
# (1797,)

# %%
train_x = np.array(inputs[:1497])
valid_x = np.array(inputs[1497:])
train_y = np.array(targets[:1497])
valid_y = np.array(targets[1497:])

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import torch
#from torchvision import datasets, models, transforms
from torchvision import models, transforms
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import time
import copy

# %%
from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, x, y):
        super(MyDataset, self).__init__()
        assert x.shape[0] == y.shape[0]
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.y.shape[0]
    
    def __getitem__(self, index):
        return self.x[index], self.y[index]

# %%
traindata = MyDataset(train_x, train_y)
validation = MyDataset(valid_x, valid_y)

# %%
image_datasets = {
    'train': 
    traindata,
    'validation': 
    validation
}

dataloaders = {
    'train':
    torch.utils.data.DataLoader(traindata,
                                batch_size=1,
                                shuffle=True, num_workers=0),
    'validation':
    torch.utils.data.DataLoader(validation,
                                batch_size=1,
                                shuffle=False, num_workers=0)
}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
print(device)
# Out:
# cuda:0

# %%
class LinReg(nn.Module):
    def __init__(self):
        super().__init__()
        self.d = 8
        self.flatten = nn.Flatten()
        self.fc0 = nn.Linear(self.d**2,50)
        self.hs0 = HardSigLayer()
        #self.relu0 = nn.ReLU()
        self.do0 = nn.Dropout(0.25)
        self.fc1 = nn.Linear(50,10)
        self.hs1 = HardSigLayer()
        #self.relu1 = nn.ReLU()
        #self.do1 = nn.Dropout(0.1)
        #self.fc2 = nn.Linear(64,2)
        #self.do2 = nn.Dropout(0.2)
        
    def forward(self, x):
        x = x.float()
        x = self.flatten(x)
        x = self.fc0(x)
        x = self.hs0.forward(x)
        #x = self.relu0(x)
        x = self.do0(x)
        x = self.fc1(x)
        x = self.hs1.forward(x)
        #x = self.relu1(x)
        #x = self.do1(x)
        #x = self.fc2(x)
        #x = self.do2(x)
        return x
    
model = LinReg().to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())
#optimizer = optim.SGD(model.fc.parameters(),lr=0.1,momentum=0.9)

# %%
def train_model(model, criterion, optimizer, num_epochs=50):
    best_acc = 0
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
            else:
                model.eval()

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.type(torch.LongTensor)
                labels = labels.to(device)

                if phase == 'validation':
                    with torch.no_grad():
                        outputs = model(inputs)
                        loss = criterion(outputs, labels)
                else:
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.detach() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc = running_corrects.float() / len(image_datasets[phase])
            if phase == 'validation' and epoch_acc > best_acc:
                print('saving best model...')
                torch.save(model.state_dict(), 'models/pytorch/weights.h5')
                best_acc = epoch_acc

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss.item(),
                                                        epoch_acc.item()))
    return model, best_acc

# %%
model_trained, accuracy = train_model(model, criterion, optimizer, num_epochs=100)
print('\nBest test accuracy: %f'%accuracy)
# Out:
# Epoch 1/100
# ----------
# train loss: 1.2775, acc: 0.8257
# saving best model...
# validation loss: 1.0940, acc: 0.8733
# Epoch 2/100
# ----------
# train loss: 0.9889, acc: 0.9345
# saving best model...
# validation loss: 1.0347, acc: 0.8900
# Epoch 3/100
# ----------
# train loss: 0.9414, acc: 0.9439
# saving best model...
# validation loss: 1.0241, acc: 0.9000
# Epoch 4/100
# ----------
# train loss: 0.9141, acc: 0.9586
# validation loss: 0.9960, acc: 0.8967
# Epoch 5/100
# ----------
# train loss: 0.8918, acc: 0.9646
# validation loss: 1.0006, acc: 0.9000
# Epoch 6/100
# ----------
# train loss: 0.8881, acc: 0.9599
# saving best model...
# validation loss: 0.9725, acc: 0.9067
# Epoch 7/100
# ----------
# train loss: 0.8886, acc: 0.9613
# saving best model...
# validation loss: 0.9720, acc: 0.9100
# Epoch 8/100
# ----------
# train loss: 0.8761, acc: 0.9666
# validation loss: 0.9837, acc: 0.9033
# Epoch 9/100
# ----------
# train loss: 0.8673, acc: 0.9746
# saving best model...
# validation loss: 0.9721, acc: 0.9167
# Epoch 10/100
# ----------
# train loss: 0.8640, acc: 0.9753
# validation loss: 0.9667, acc: 0.9167
# Epoch 11/100
# ----------
# train loss: 0.8601, acc: 0.9773
# saving best model...
# validation loss: 0.9695, acc: 0.9267
# Epoch 12/100
# ----------
# train loss: 0.8601, acc: 0.9726
# validation loss: 0.9551, acc: 0.8967
# Epoch 13/100
# ----------
# train loss: 0.8517, acc: 0.9800
# validation loss: 0.9692, acc: 0.9233
# Epoch 14/100
# ----------
# train loss: 0.8537, acc: 0.9786
# validation loss: 0.9627, acc: 0.9133
# Epoch 15/100
# ----------
# train loss: 0.8483, acc: 0.9826
# validation loss: 0.9826, acc: 0.9000
# Epoch 16/100
# ----------
# train loss: 0.8500, acc: 0.9786
# validation loss: 0.9557, acc: 0.9167
# Epoch 17/100
# ----------
# train loss: 0.8495, acc: 0.9733
# saving best model...
# validation loss: 0.9565, acc: 0.9300
# Epoch 18/100
# ----------
# train loss: 0.8381, acc: 0.9853
# validation loss: 0.9562, acc: 0.9200
# Epoch 19/100
# ----------
# train loss: 0.8461, acc: 0.9800
# validation loss: 0.9397, acc: 0.9300
# Epoch 20/100
# ----------
# train loss: 0.8385, acc: 0.9866
# validation loss: 0.9417, acc: 0.9167
# Epoch 21/100
# ----------
# train loss: 0.8380, acc: 0.9793
# validation loss: 0.9528, acc: 0.9067
# Epoch 22/100
# ----------
# train loss: 0.8447, acc: 0.9793
# validation loss: 0.9551, acc: 0.9133
# Epoch 23/100
# ----------
# train loss: 0.8389, acc: 0.9840
# validation loss: 0.9500, acc: 0.9200
# Epoch 24/100
# ----------
# train loss: 0.8342, acc: 0.9900
# validation loss: 0.9518, acc: 0.9200
# Epoch 25/100
# ----------
# train loss: 0.8371, acc: 0.9840
# validation loss: 0.9546, acc: 0.9133
# Epoch 26/100
# ----------
# train loss: 0.8347, acc: 0.9860
# validation loss: 0.9597, acc: 0.9100
# Epoch 27/100
# ----------
# train loss: 0.8336, acc: 0.9886
# validation loss: 0.9543, acc: 0.9233
# Epoch 28/100
# ----------
# train loss: 0.8333, acc: 0.9853
# validation loss: 0.9553, acc: 0.9067
# Epoch 29/100
# ----------
# train loss: 0.8298, acc: 0.9866
# validation loss: 0.9497, acc: 0.9267
# Epoch 30/100
# ----------
# train loss: 0.8308, acc: 0.9866
# validation loss: 0.9505, acc: 0.9133
# Epoch 31/100
# ----------
# train loss: 0.8332, acc: 0.9826
# validation loss: 0.9547, acc: 0.9233
# Epoch 32/100
# ----------
# train loss: 0.8358, acc: 0.9813
# validation loss: 0.9516, acc: 0.9233
# Epoch 33/100
# ----------
# train loss: 0.8271, acc: 0.9893
# validation loss: 0.9481, acc: 0.9167
# Epoch 34/100
# ----------
# train loss: 0.8252, acc: 0.9880
# validation loss: 0.9599, acc: 0.9133
# Epoch 35/100
# ----------
# train loss: 0.8331, acc: 0.9880
# validation loss: 0.9503, acc: 0.9167
# Epoch 36/100
# ----------
# train loss: 0.8292, acc: 0.9873
# validation loss: 0.9572, acc: 0.9100
# Epoch 37/100
# ----------
# train loss: 0.8287, acc: 0.9853
# validation loss: 0.9651, acc: 0.9100
# Epoch 38/100
# ----------
# train loss: 0.8294, acc: 0.9873
# validation loss: 0.9697, acc: 0.9067
# Epoch 39/100
# ----------
# train loss: 0.8258, acc: 0.9880
# validation loss: 0.9479, acc: 0.9167
# Epoch 40/100
# ----------
# train loss: 0.8279, acc: 0.9860
# validation loss: 0.9438, acc: 0.9233
# Epoch 41/100
# ----------
# train loss: 0.8240, acc: 0.9866
# validation loss: 0.9458, acc: 0.9233
# Epoch 42/100
# ----------
# train loss: 0.8267, acc: 0.9906
# validation loss: 0.9483, acc: 0.9200
# Epoch 43/100
# ----------
# train loss: 0.8268, acc: 0.9860
# validation loss: 0.9686, acc: 0.9100
# Epoch 44/100
# ----------
# train loss: 0.8235, acc: 0.9900
# validation loss: 0.9600, acc: 0.9100
# Epoch 45/100
# ----------
# train loss: 0.8253, acc: 0.9886
# validation loss: 0.9442, acc: 0.9100
# Epoch 46/100
# ----------
# train loss: 0.8197, acc: 0.9886
# validation loss: 0.9374, acc: 0.9233
# Epoch 47/100
# ----------
# train loss: 0.8258, acc: 0.9893
# validation loss: 0.9660, acc: 0.9067
# Epoch 48/100
# ----------
# train loss: 0.8273, acc: 0.9866
# validation loss: 0.9518, acc: 0.9133
# Epoch 49/100
# ----------
# train loss: 0.8184, acc: 0.9833
# validation loss: 0.9583, acc: 0.9033
# Epoch 50/100
# ----------
# train loss: 0.8238, acc: 0.9893
# validation loss: 0.9623, acc: 0.9100
# Epoch 51/100
# ----------
# train loss: 0.8219, acc: 0.9900
# validation loss: 0.9678, acc: 0.9200
# Epoch 52/100
# ----------
# train loss: 0.8187, acc: 0.9940
# validation loss: 0.9478, acc: 0.9167
# Epoch 53/100
# ----------
# train loss: 0.8216, acc: 0.9927
# validation loss: 0.9400, acc: 0.9233
# Epoch 54/100
# ----------
# train loss: 0.8214, acc: 0.9900
# validation loss: 0.9590, acc: 0.9200
# Epoch 55/100
# ----------
# train loss: 0.8237, acc: 0.9880
# validation loss: 0.9798, acc: 0.9000
# Epoch 56/100
# ----------
# train loss: 0.8220, acc: 0.9886
# validation loss: 0.9638, acc: 0.9167
# Epoch 57/100
# ----------
# train loss: 0.8236, acc: 0.9906
# validation loss: 0.9605, acc: 0.9100
# Epoch 58/100
# ----------
# train loss: 0.8177, acc: 0.9893
# validation loss: 0.9584, acc: 0.9167
# Epoch 59/100
# ----------
# train loss: 0.8213, acc: 0.9920
# validation loss: 0.9671, acc: 0.9067
# Epoch 60/100
# ----------
# train loss: 0.8227, acc: 0.9913
# validation loss: 0.9612, acc: 0.9067
# Epoch 61/100
# ----------
# train loss: 0.8207, acc: 0.9906
# validation loss: 0.9628, acc: 0.9167
# Epoch 62/100
# ----------
# train loss: 0.8210, acc: 0.9927
# validation loss: 0.9596, acc: 0.9167
# Epoch 63/100
# ----------
# train loss: 0.8169, acc: 0.9973
# validation loss: 0.9755, acc: 0.8967
# Epoch 64/100
# ----------
# train loss: 0.8144, acc: 0.9933
# validation loss: 0.9423, acc: 0.9167
# Epoch 65/100
# ----------
# train loss: 0.8205, acc: 0.9927
# validation loss: 0.9605, acc: 0.9100
# Epoch 66/100
# ----------
# train loss: 0.8198, acc: 0.9873
# validation loss: 0.9706, acc: 0.9100
# Epoch 67/100
# ----------
# train loss: 0.8162, acc: 0.9940
# validation loss: 0.9817, acc: 0.9100
# Epoch 68/100
# ----------
# train loss: 0.8202, acc: 0.9920
# validation loss: 0.9540, acc: 0.9200
# Epoch 69/100
# ----------
# train loss: 0.8165, acc: 0.9913
# validation loss: 0.9646, acc: 0.9067
# Epoch 70/100
# ----------
# train loss: 0.8184, acc: 0.9927
# validation loss: 0.9527, acc: 0.9133
# Epoch 71/100
# ----------
# train loss: 0.8200, acc: 0.9940
# validation loss: 0.9587, acc: 0.9067
# Epoch 72/100
# ----------
# train loss: 0.8171, acc: 0.9913
# validation loss: 0.9780, acc: 0.9067
# Epoch 73/100
# ----------
# train loss: 0.8163, acc: 0.9960
# validation loss: 0.9773, acc: 0.9000
# Epoch 74/100
# ----------
# train loss: 0.8151, acc: 0.9927
# validation loss: 0.9284, acc: 0.9267
# Epoch 75/100
# ----------
# train loss: 0.8195, acc: 0.9933
# validation loss: 0.9500, acc: 0.9167
# Epoch 76/100
# ----------
# train loss: 0.8174, acc: 0.9913
# validation loss: 0.9563, acc: 0.9067
# Epoch 77/100
# ----------
# train loss: 0.8150, acc: 0.9960
# validation loss: 0.9660, acc: 0.9100
# Epoch 78/100
# ----------
# train loss: 0.8200, acc: 0.9900
# validation loss: 0.9611, acc: 0.9200
# Epoch 79/100
# ----------
# train loss: 0.8126, acc: 0.9947
# saving best model...
# validation loss: 0.9295, acc: 0.9333
# Epoch 80/100
# ----------
# train loss: 0.8192, acc: 0.9947
# validation loss: 0.9613, acc: 0.9100
# Epoch 81/100
# ----------
# train loss: 0.8117, acc: 0.9947
# validation loss: 0.9408, acc: 0.9233
# Epoch 82/100
# ----------
# train loss: 0.8184, acc: 0.9873
# validation loss: 0.9853, acc: 0.9033
# Epoch 83/100
# ----------
# train loss: 0.8162, acc: 0.9920
# validation loss: 0.9728, acc: 0.9033
# Epoch 84/100
# ----------
# train loss: 0.8128, acc: 0.9953
# validation loss: 0.9635, acc: 0.9133
# Epoch 85/100
# ----------
# train loss: 0.8151, acc: 0.9960
# validation loss: 0.9667, acc: 0.9133
# Epoch 86/100
# ----------
# train loss: 0.8109, acc: 0.9960
# validation loss: 0.9636, acc: 0.9167
# Epoch 87/100
# ----------
# train loss: 0.8113, acc: 0.9940
# validation loss: 0.9570, acc: 0.9233
# Epoch 88/100
# ----------
# train loss: 0.8151, acc: 0.9893
# validation loss: 0.9462, acc: 0.9133
# Epoch 89/100
# ----------
# train loss: 0.8124, acc: 0.9947
# validation loss: 0.9426, acc: 0.9233
# Epoch 90/100
# ----------
# train loss: 0.8121, acc: 0.9940
# validation loss: 0.9616, acc: 0.9133
# Epoch 91/100
# ----------
# train loss: 0.8115, acc: 0.9967
# validation loss: 0.9486, acc: 0.9167
# Epoch 92/100
# ----------
# train loss: 0.8139, acc: 0.9920
# validation loss: 0.9814, acc: 0.9067
# Epoch 93/100
# ----------
# train loss: 0.8148, acc: 0.9933
# validation loss: 0.9803, acc: 0.9033
# Epoch 94/100
# ----------
# train loss: 0.8188, acc: 0.9940
# validation loss: 0.9575, acc: 0.9133
# Epoch 95/100
# ----------
# train loss: 0.8130, acc: 0.9940
# validation loss: 0.9498, acc: 0.9233
# Epoch 96/100
# ----------
# train loss: 0.8124, acc: 0.9960
# validation loss: 0.9635, acc: 0.9167
# Epoch 97/100
# ----------
# train loss: 0.8116, acc: 0.9953
# validation loss: 0.9540, acc: 0.9167
# Epoch 98/100
# ----------
# train loss: 0.8142, acc: 0.9927
# validation loss: 0.9623, acc: 0.9100
# Epoch 99/100
# ----------
# train loss: 0.8170, acc: 0.9906
# validation loss: 0.9692, acc: 0.9133
# Epoch 100/100
# ----------
# train loss: 0.8085, acc: 0.9947
# validation loss: 0.9890, acc: 0.9067
#
# Best test accuracy: 0.933333

# %%
model.load_state_dict(torch.load('models/pytorch/hsig_9333_acc.h5'))
# Out:
# <All keys matched successfully>

# %%
for name, param in model.named_parameters():
    print('name: ', name)
    print(type(param))
    print('param.shape: ', param.shape)
    print('param.requires_grad: ', param.requires_grad)
    print('=====')
# Out:
# name:  fc0.weight
# <class 'torch.nn.parameter.Parameter'>
# param.shape:  torch.Size([50, 64])
# param.requires_grad:  True
# =====
# name:  fc0.bias
# <class 'torch.nn.parameter.Parameter'>
# param.shape:  torch.Size([50])
# param.requires_grad:  True
# =====
# name:  fc1.weight
# <class 'torch.nn.parameter.Parameter'>
# param.shape:  torch.Size([10, 50])
# param.requires_grad:  True
# =====
# name:  fc1.bias
# <class 'torch.nn.parameter.Parameter'>
# param.shape:  torch.Size([10])
# param.requires_grad:  True
# =====

# %%
W1 = model.fc0.weight.cpu().detach().numpy().T
print(W1.shape)
np.save('w1.npy',W1)
# Out:
# (64, 50)

# %%
W2 = model.fc1.weight.cpu().detach().numpy().T
print(W2.shape)
np.save('w2.npy',W2)
# Out:
# (50, 10)

# %%
bh = model.fc0.bias.cpu().detach().numpy()
print(bh.shape)
np.save('bh.npy',bh)
# Out:
# (50,)

# %%
by = model.fc1.bias.cpu().detach().numpy()
print(by.shape)
np.save('by.npy',by)
# Out:
# (10,)
